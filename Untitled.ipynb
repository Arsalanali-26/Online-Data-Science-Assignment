# %%
import pandas as pd

# %%
data = pd.read_csv("Crown-Contacts.csv",index_col=0)
data.head()
# Out:
#             First Name  Middle Name  Last Name  Suffix  Company Department  \
# Title
# NaN    Amir Abdul Aziz          NaN        NaN     NaN      NaN    Finance
# NaN       Abdul Mannan          NaN        NaN     NaN      NaN      Claim
# NaN       Abdul Rehman          NaN        NaN     NaN      NaN      Brand
# NaN      Adnan Suleman          NaN        NaN     NaN      NaN        NaN
# NaN         Ahsan Ejaz          NaN        NaN     NaN      NaN      R & D
#
#                     Job Title  Business Street  Business Street 2  \
# Title
# NaN         Assistant Manager              NaN                NaN
# NaN     Asst Claim Supervisor              NaN                NaN
# NaN    Executive Video Editor              NaN                NaN
# NaN        Data Entry Officer              NaN                NaN
# NaN         Associate Manager              NaN                NaN
#
#        Business Street 3  ...  Private  Profession  Referred By  Sensitivity  \
# ...

# %%
data.tile()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-038315f854c0> in <module>
# ----> 1 data.tile()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tile'

# %%
data.shape
# Out:
# (159, 92)

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6208d269f320> in <module>
# ----> 1 data.info()
#
# NameError: name 'data' is not defined
